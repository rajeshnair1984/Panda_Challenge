# %%
import pandas as pd

# %%
path = "Resources/purchase_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Player Count

players = df.SN.unique()
total_players = len(players)
total_players
total_players_df = {'Total Players':[total_players]}
tot_players = pd.DataFrame(total_players_df, index = [0])
tot_players
# Out:
#    Total Players
# 0            576

# %%
# Purchasing Analysis(Total)

# Number of unique items
unique_item = df["Item ID"].unique()
total_unique_item = len(unique_item)

# Total number of purchases
total_id = df["Purchase ID"].count()

# Total Revenue
total_price = df["Price"].sum()

# Average Price
average_df = total_price / total_id

# Adding summary table

summary_df = {'Number of Unique Itmes':[total_unique_item],'Average Price':[average_df],
             'Number of Purchases':[total_id],'Total Revenue':[total_price]}
summary_df = pd.DataFrame(summary_df,index = [0])
summary_df.style.format({"Average Price": "${:,.2f}","Total Revenue": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Itmes</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_0e376f4e_981b_11eb_ac8f_1cbfc090a2f4row0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %%
# Gender Demographics

male = df.loc[df["Gender"] == "Male"]
male
unique_male = male["SN"].unique()
unique_males = len(unique_male)

female = df.loc[df["Gender"] == "Female"]
female
unique_female = female["SN"].unique()
unique_females = len(unique_female)

other = df.loc[df["Gender"] == "Other / Non-Disclosed"]
other
unique_other = other["SN"].unique()
unique_others = len(unique_other)

Per_Male = (unique_males/total_players)*100
# print(Per_Male)

Per_Female = (unique_females/total_players)*100
# print(Per_Female)

Per_Others = (unique_others/total_players)*100
# print(Per_Others)


summary_gender_df = {"Total Count":[unique_males,unique_females,unique_others],"Percentage of Players":[Per_Male,Per_Female,Per_Others]}

summary_gender_df = pd.DataFrame(summary_gender_df,index = ["Male","Female","Other / Non-Disclosed"])
summary_gender_df
summary_gender_df.style.format({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row1_col0" class="data row1 col0" >81</td>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row1_col1" class="data row1 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_0fa941ff_981b_11eb_ba22_1cbfc090a2f4row2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %%
# Purchasing Analysis(Gender)
df.head()
group_gender = df.groupby(["Gender"])
group_gender.count()
gender_count = group_gender['Purchase ID'].count()
gender_count
average_purchase =group_gender['Price'].mean()
average_purchase
total_purchase = group_gender['Price'].sum()
total_purchase
summary_gender = {'Purchase Count':gender_count,'Average Purchase Price':average_purchase,
                  'Total Purchase Value':total_purchase}
summary_gender = pd.DataFrame(summary_gender)

total = summary_gender['Total Purchase Value']
summary_gender['Avg Total Purchase per Person'] = [summary_gender.iloc[0,2]/unique_females,
                                                   summary_gender.iloc[1,2]/unique_males,
                                                   summary_gender.iloc[2,2]/unique_others]
summary_gender.style.format({"Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}",
                             "Avg Total Purchase per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_111efef5_981b_11eb_8d7a_1cbfc090a2f4row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
# Age Demographics

bin = [0,9,14,19,24,29,34,39,100]
group = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
df["Age Ranges"] = pd.cut(df["Age"], bin, labels=group, include_lowest=False)
df.head()
less_10 = df.loc[df["Age Ranges"] == "<10"]
unique_less_10 = less_10["SN"].unique()
unique_less_10 = len(unique_less_10)

less_1014 = df.loc[df["Age Ranges"] == "10-14"]
unique_less_1014 = less_1014["SN"].unique()
unique_less_1014 = len(unique_less_1014)

less_1519 = df.loc[df["Age Ranges"] == "15-19"]
unique_less_1519 = less_1519["SN"].unique()
unique_less_1519 = len(unique_less_1519)

less_2024 = df.loc[df["Age Ranges"] == "20-24"]
unique_less_2024 = less_2024["SN"].unique()
unique_less_2024 = len(unique_less_2024)

less_2529 = df.loc[df["Age Ranges"] == "25-29"]
unique_less_2529 = less_2529["SN"].unique()
unique_less_2529 = len(unique_less_2529)

less_3034 = df.loc[df["Age Ranges"] == "30-34"]
unique_less_3034 = less_3034["SN"].unique()
unique_less_3034 = len(unique_less_3034)

less_3539 = df.loc[df["Age Ranges"] == "35-39"]
unique_less_3539 = less_3539["SN"].unique()
unique_less_3539 = len(unique_less_3539)

less_40 = df.loc[df["Age Ranges"] == "40+"]
unique_less_40 = less_40["SN"].unique()
unique_less_40 = len(unique_less_40)

p1 = (unique_less_10/total_players)*100
p2 = (unique_less_1014/total_players)*100
p3 = (unique_less_1519/total_players)*100
p4 = (unique_less_2024/total_players)*100
p5 = (unique_less_2529/total_players)*100
p6 = (unique_less_3034/total_players)*100
p7 = (unique_less_3539/total_players)*100
p8 = (unique_less_40/total_players)*100


summary_agedemo = {"Total Count":[unique_less_10,unique_less_1014,unique_less_1519,unique_less_2024,unique_less_2529,unique_less_3034,unique_less_3539,
        unique_less_40],"Percentage of Players":[p1,p2,p3,p4,p5,p6,p7,p8]}
summary_agedemo = pd.DataFrame(summary_agedemo,index=["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"])
summary_agedemo
summary_agedemo.style.format({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_12d4c489_981b_11eb_8be4_1cbfc090a2f4row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
# Purchasing Analysis
bin = [0,9,14,19,24,29,34,39,100]
group = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
df["Age Ranges"] = pd.cut(df["Age"], bin, labels=group, include_lowest=False)
df.head()

group_range = df.groupby(['Age Ranges'])
range_count = group_range['Purchase ID'].count()
range_count
range_price = group_range['Price'].sum()
range_price
range_average = group_range['Price'].mean()
range_average
summary_ranges = {'Purchase Count':range_count,'Average Purchase Price':range_average,
                  'Total Purchase Value':range_price}
summary_ranges = pd.DataFrame(summary_ranges)
summary_ranges
summary_ranges['Avg Total Purchase per Person'] = [summary_ranges.iloc[0,2]/unique_less_10,
                                                   summary_ranges.iloc[1,2]/unique_less_1014,
                                                   summary_ranges.iloc[2,2]/unique_less_1519,
                                                  summary_ranges.iloc[3,2]/unique_less_2024,
                                                  summary_ranges.iloc[4,2]/unique_less_2529,
                                                  summary_ranges.iloc[5,2]/unique_less_3034,
                                                  summary_ranges.iloc[6,2]/unique_less_3539,
                                                  summary_ranges.iloc[7,2]/unique_less_40,]
summary_ranges.style.format({"Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}",
                             "Avg Total Purchase per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_15a854cf_981b_11eb_846d_1cbfc090a2f4row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
# Top Spenders
df.head()
group_sn = df.groupby(["SN"])
group_sn_counts = group_sn["Purchase ID"].count()
group_sn_counts

total_purchase = group_sn["Price"].sum()
total_purchase
average = (group_sn["Price"].sum()) / group_sn_counts
average
summary_topspender = pd.DataFrame({"Purchase Count":group_sn_counts,
                                   "Average Purchase Price":average,
                                   "Total Purchase Value":total_purchase})
summary_topspender
summary_sort_topspender = summary_topspender.head().sort_values("Total Purchase Value", ascending=False)

summary_sort_topspender.style.format({"Average Purchase Price":"${:.2f}","Total Purchase Value":"${:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >Aeda94</th>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row0_col1" class="data row0 col1" >$4.91</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row0_col2" class="data row0 col2" >$4.91</td>
#             </tr>
#             <tr>
#                         <th id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >Adastirin33</th>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row1_col1" class="data row1 col1" >$4.48</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row1_col2" class="data row1 col2" >$4.48</td>
#             </tr>
#             <tr>
#                         <th id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >Aela59</th>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row2_col1" class="data row2 col1" >$4.32</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row2_col2" class="data row2 col2" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4level0_row3" class="row_heading level0 row3" >Adairialis76</th>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row3_col1" class="data row3 col1" >$2.28</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row3_col2" class="data row3 col2" >$2.28</td>
#             </tr>
#             <tr>
#                         <th id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4level0_row4" class="row_heading level0 row4" >Aelaria33</th>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row4_col1" class="data row4 col1" >$1.79</td>
#                         <td id="T_236afc5b_981b_11eb_b184_1cbfc090a2f4row4_col2" class="data row4 col2" >$1.79</td>
#             </tr>
#     </tbody></table>

# %%
# Most Popular item
total_item = df.groupby(["Item ID","Item Name"])
pur_count = total_item["Purchase ID"].count()
pur_count
purchase_value = total_item["Price"].sum()
purchase_value
item_price = purchase_value / pur_count
item_price

summary_mostpop = pd.DataFrame({"Purchase Count":pur_count,"Item Price":item_price,"Total Purchase Value":purchase_value})
summary_mostpop
summary_sort_mostpop = summary_mostpop.head().sort_values("Purchase Count", ascending=False)
summary_sort_mostpop.style.format({"Item Price":"${:.2f}","Total Purchase Value":"${:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >2</th>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level1_row0" class="row_heading level1 row0" >Verdict</th>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row0_col1" class="data row0 col1" >$2.48</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row0_col2" class="data row0 col2" >$14.88</td>
#             </tr>
#             <tr>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >3</th>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level1_row1" class="row_heading level1 row1" >Phantomlight</th>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row1_col0" class="data row1 col0" >6</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row1_col1" class="data row1 col1" >$2.49</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row1_col2" class="data row1 col2" >$14.94</td>
#             </tr>
#             <tr>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >4</th>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level1_row2" class="row_heading level1 row2" >Bloodlord's Fetish</th>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row2_col1" class="data row2 col1" >$1.70</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row2_col2" class="data row2 col2" >$8.50</td>
#             </tr>
#             <tr>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level0_row3" class="row_heading level0 row3" >0</th>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level1_row3" class="row_heading level1 row3" >Splinter</th>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row3_col1" class="data row3 col1" >$1.28</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row3_col2" class="data row3 col2" >$5.12</td>
#             </tr>
#             <tr>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level0_row4" class="row_heading level0 row4" >1</th>
#                         <th id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4level1_row4" class="row_heading level1 row4" >Crucifer</th>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row4_col1" class="data row4 col1" >$2.94</td>
#                         <td id="T_29c51b97_981b_11eb_99ac_1cbfc090a2f4row4_col2" class="data row4 col2" >$11.77</td>
#             </tr>
#     </tbody></table>

# %%
# Most Profitable Item
summary_sort_mostpop = summary_mostpop.sort_values("Total Purchase Value", ascending=False)
summary_sort_mostpop
summary_sort_mostpop.head().style.format({"Item Price":"${:.2f}","Total Purchase Value":"${:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_2fe5dd6a_981b_11eb_b169_1cbfc090a2f4row4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Three Observable Trends
#
# 1 Percentage of Male players dominates the game with 84.03%.
#
# 2 Even though Male dominates in numbers,spending per person figure shows Females are ahead in spending.
#
# 3 Maximum purchase are done by players between age group 20 - 24.
